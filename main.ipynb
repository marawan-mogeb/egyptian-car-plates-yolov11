# %%
from ultralytics import YOLO
import cv2

from sort.sort import *

# %%
yolo_model=YOLO('yolo11n.pt')
plate_model=YOLO('plate.pt') #plate detection model
model_ocr = YOLO("best.pt")  #  OCR model

# %%
def detect_and_crop_plate(image_path, yolo_model, plate_model):
    """
    Detect and crop license plate from an image
    
    Args:
        image_path (str): Path to the input image
        yolo_model: YOLO model for object detection
        plate_model: Model for license plate detection
    """
    # Read and convert image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("Could not read the image")
        
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform detections
    detections = yolo_model(image_rgb)[0]
    plates = plate_model(image_rgb)[0]

    # Plot the original image
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)
    plt.axis("off")

    # Variable to store cropped plate
    plate_cropped = None

    # Loop through detected plates
    for plate in plates.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = plate

        # Crop the detected plate
        plate_cropped = image_rgb[int(y1):int(y2), int(x1):int(x2)]
        
        # Show cropped plate
        plt.figure(figsize=(3, 2))
        plt.imshow(plate_cropped)
        plt.axis("off")

    plt.show()
    
    return plate_cropped

# Usage example:
try:
    cropped_plate = detect_and_crop_plate('download_9.jpg', yolo_model, plate_model)
    if cropped_plate is not None:
        print("Plate cropped successfully.")
    else:
        print("No plate detected or cropped.")
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# 0: 640x640 2 cars, 1 bus, 188.8ms
# Speed: 12.3ms preprocess, 188.8ms inference, 13.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License Plate, 85.7ms
# Speed: 5.6ms preprocess, 85.7ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 640)
# Plate cropped successfully.

# %%
def process_license_plate(image_path):
    # Read the image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("Could not read the image")

    # Convert BGR to RGB
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Load model and make predictions
    model_ocr = YOLO('best.pt')
    result = model_ocr.predict(source=image_rgb, conf=0.25)[0]

    detected_numbers = []
    detected_letters = []

    # Sort boxes by x-coordinate (left to right)
    sorted_boxes = sorted(result.boxes, key=lambda b: b.xyxy[0][0].item())

    # Process each detected character
    for box in sorted_boxes:
        class_id = int(box.cls)
        
        if class_id in result.names:
            recognized_text = result.names[class_id]
            
            # Add to appropriate list
            if recognized_text.isdigit():
                detected_numbers.append(recognized_text)
            else:
                detected_letters.append(recognized_text)

    # Print the detected numbers and letters, preserving their original order
    print("Detected Numbers:", detected_numbers)
    print("Detected Letters:", detected_letters)

    # Visualize results
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)
    plt.axis('off')
    plt.show()

# Use the function
try:
    process_license_plate('Figure_1.0.png')
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# 0: 448x640 1 1, 1 3, 1 5, 1 6, 1 faa, 1 jeem, 1 waw, 73.6ms
# Speed: 2.5ms preprocess, 73.6ms inference, 1.1ms postprocess per image at shape (1, 3, 448, 640)
# Detected Numbers: ['1', '3', '6', '5']
# Detected Letters: ['faa', 'waw', 'jeem']

# %%
# This code is a complete pipeline for license plate detection, cropping, and OCR without arabic maping
def license_plate_detection_pipeline(image_path, yolo_model, plate_model, ocr_model):
    """
    Complete pipeline for license plate detection, cropping, and OCR
    
    Args:
        image_path (str): Path to the input image
        yolo_model: YOLO model for object detection
        plate_model: Model for license plate detection
        ocr_model: Model for OCR (text recognition)
    """
    # Read and convert image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("Could not read the image")
        
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform detections
    detections = yolo_model(image_rgb)[0]
    plates = plate_model(image_rgb)[0]

    # Plot the original image
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)
    plt.axis("off")

    # Variables to store results
    plate_cropped = None
    detected_numbers = []
    detected_letters = []

    # Loop through detected plates
    for plate in plates.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = plate

        # Crop the detected plate
        plate_cropped = image_rgb[int(y1):int(y2), int(x1):int(x2)]
        
        # Show cropped plate
        plt.figure(figsize=(3, 2))
        plt.imshow(plate_cropped)
        plt.axis("off")

        # Perform OCR on the cropped plate
        result = ocr_model.predict(source=plate_cropped, conf=0.25)[0]
        
        # Sort boxes left to right
        sorted_boxes = sorted(result.boxes, key=lambda b: b.xyxy[0][0].item())

        # Process each detected character
        for box in sorted_boxes:
            class_id = int(box.cls)
            
            if class_id in result.names:
                recognized_text = result.names[class_id]
                
                # Add to appropriate list
                if recognized_text.isdigit():
                    detected_numbers.append(recognized_text)
                else:
                    detected_letters.append(recognized_text)

    # Print the detected numbers and letters
    print("Detected Numbers:", detected_numbers)
    print("Detected Letters:", detected_letters)

    plt.show()
    
    return plate_cropped, detected_numbers, detected_letters

# Usage example:
try:
    cropped_plate, numbers, letters = license_plate_detection_pipeline(
        'download_15.jpg',
        yolo_model,
        plate_model,
        model_ocr  # Your OCR model
    )
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# 0: 640x640 4 cars, 1 truck, 108.6ms
# Speed: 6.7ms preprocess, 108.6ms inference, 5.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License Plate, 94.4ms
# Speed: 6.1ms preprocess, 94.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 320x640 2 2s, 2 3s, 1 alif, 1 daal, 1 seen, 135.0ms
# Speed: 5.4ms preprocess, 135.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# Detected Numbers: ['2', '2', '3', '3']
# Detected Letters: ['daal', 'seen', 'alif']

# %%
#full pipeline with arabic mapping 
def map_to_arabic(numbers, letters):
    # Dictionary for number mapping (English to Arabic)
    number_map = {
        '0': '٠', '1': '١', '2': '٢', '3': '٣', '4': '٤',
        '5': '٥', '6': '٦', '7': '٧', '8': '٨', '9': '٩'
    }
    
    letter_map = {
        'alif': 'ا', 'baa': 'ب', 'taa': 'ت', 'thaa': 'ث',
        'jeem': 'ج', 'haa': 'ح', 'khaa': 'خ', 'daal': 'د',
        'zaal': 'ذ', 'raa': 'ر', 'zay': 'ز', 'seen': 'س',
        'sheen': 'ش', 'saad': 'ص', 'daad': 'ض', 'Taa': 'ط',
        'Thaa': 'ظ', 'ain': 'ع', 'ghayn': 'غ', 'faa': 'ف',
        'qaaf': 'ق', 'kaaf': 'ك', 'laam': 'ل', 'meem': 'م',
        'noon': 'ن', 'haa': 'ه', 'waw': 'و', 'yaa': 'ي',
        '7aa': 'ح'
    }
    
    # Convert numbers
    arabic_numbers = [number_map[num] for num in numbers]
    
    # Convert letters
    arabic_letters = [letter_map[letter] for letter in reversed(letters)]
    
    # Combine numbers and letters with space
    result = ' '.join(arabic_letters + arabic_numbers )
    
    return result

def license_plate_detection_pipeline(image_path, yolo_model, plate_model, ocr_model):
    """
    Complete pipeline for license plate detection, cropping, and OCR
    
    Args:
        image_path (str): Path to the input image
        yolo_model: YOLO model for object detection
        plate_model: Model for license plate detection
        ocr_model: Model for OCR (text recognition)
    """
    # Read and convert image
    image = cv2.imread(image_path)
    if image is None:
        raise ValueError("Could not read the image")
        
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

    # Perform detections
    plates = plate_model(image_rgb)[0]

    # Plot the original image
    plt.figure(figsize=(10, 6))
    plt.imshow(image_rgb)
    plt.axis("off")

    # Variables to store results
    plate_cropped = None
    detected_numbers = []
    detected_letters = []

    # Loop through detected plates
    for plate in plates.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = plate

        # Crop the detected plate
        plate_cropped = image_rgb[int(y1):int(y2), int(x1):int(x2)]
        
        # Show cropped plate
        plt.figure(figsize=(3, 2))
        plt.imshow(plate_cropped)
        plt.axis("off")

        # Perform OCR on the cropped plate
        result = ocr_model.predict(source=plate_cropped, conf=0.25)[0]
        
        # Sort boxes left to right
        sorted_boxes = sorted(result.boxes, key=lambda b: b.xyxy[0][0].item())

        # Process each detected character
        for box in sorted_boxes:
            class_id = int(box.cls)
            
            if class_id in result.names:
                recognized_text = result.names[class_id]
                
                # Add to appropriate list
                if recognized_text.isdigit():
                    detected_numbers.append(recognized_text)
                else:
                    detected_letters.append(recognized_text)

    # Print the detected numbers and letters
    arabic_text = map_to_arabic(detected_numbers, detected_letters)
    print(f"License plate in Arabic: {arabic_text}")
    plt.show()
    
    return plate_cropped, arabic_text

# Usage example:
try:
    cropped_plate, arabic_text = license_plate_detection_pipeline(
        'download_7.jpg',
        yolo_model,
        plate_model,
        model_ocr  # Your OCR model
    )
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# 0: 640x512 1 License Plate, 140.9ms
# Speed: 3.6ms preprocess, 140.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 512)
#
# 0: 608x640 4 1s, 2 meems, 1 waw, 90.5ms
# Speed: 3.2ms preprocess, 90.5ms inference, 0.9ms postprocess per image at shape (1, 3, 608, 640)
# License plate in Arabic: م و م ١ ١ ١ ١

# %%
##video pipeline but it is not working perfectly
def map_to_arabic(numbers, letters):
    # Dictionary for number mapping (English to Arabic)
    number_map = {
        '0': '٠', '1': '١', '2': '٢', '3': '٣', '4': '٤',
        '5': '٥', '6': '٦', '7': '٧', '8': '٨', '9': '٩'
    }
    
    letter_map = {
        'alif': 'ا', 'baa': 'ب', 'taa': 'ت', 'thaa': 'ث',
        'jeem': 'ج', 'haa': 'ح', 'khaa': 'خ', 'daal': 'د',
        'zaal': 'ذ', 'raa': 'ر', 'zay': 'ز', 'seen': 'س',
        'sheen': 'ش', 'saad': 'ص', 'daad': 'ض', 'Taa': 'ط',
        'Thaa': 'ظ', 'ain': 'ع', 'ghayn': 'غ', 'faa': 'ف',
        'qaaf': 'ق', 'kaaf': 'ك', 'laam': 'ل', 'meem': 'م',
        'noon': 'ن', 'haa': 'ه', 'waw': 'و', 'yaa': 'ي',
        '7aa': 'ح'
    }
    
    # Convert numbers
    arabic_numbers = [number_map[num] for num in numbers]
    
    # Convert letters
    arabic_letters = [letter_map[letter] for letter in reversed(letters)]
    
    # Combine numbers and letters with space
    result = ' '.join(arabic_letters + arabic_numbers )
    
    return result


def process_uploaded_video(video_path, yolo_model, plate_model, ocr_model, min_conf_threshold=0.25):
    """
    Process uploaded video for license plate detection and OCR,
    storing all detections and selecting the best one based on mean confidence
    """
    video = cv2.VideoCapture(video_path)
    if not video.isOpened():
        raise ValueError("Could not read the video file")

    total_frames = int(video.get(cv2.CAP_PROP_FRAME_COUNT))
    all_detections = []  # Store all plate detections

    while True:
        ret, frame = video.read()
        if not ret:
            break
            
        frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        plates = plate_model(frame_rgb)[0]

        for plate in plates.boxes.data.tolist():
            x1, y1, x2, y2, score, class_id = plate
            
            plate_cropped = frame_rgb[int(y1):int(y2), int(x1):int(x2)]
            result = ocr_model.predict(source=plate_cropped, conf=min_conf_threshold)[0]
            
            # Sort boxes left to right
            sorted_boxes = sorted(result.boxes, key=lambda b: b.xyxy[0][0].item())

            # Process detected characters
            detected_chars = []
            
            for box in sorted_boxes:
                class_id = int(box.cls)
                conf_score = float(box.conf)
                
                if class_id in result.names:
                    char = result.names[class_id]
                    detected_chars.append({
                        'char': char,
                        'confidence': conf_score
                    })

            # Store this detection if characters were found
            if detected_chars:
                mean_confidence = sum(d['confidence'] for d in detected_chars) / len(detected_chars)
                all_detections.append({
                    'chars': detected_chars,
                    'plate_crop': plate_cropped,
                    'mean_confidence': mean_confidence
                })

        # Display progress
        current_frame = int(video.get(cv2.CAP_PROP_POS_FRAMES))
        progress = (current_frame / total_frames) * 100
        print(f"\rProcessing: {progress:.1f}%", end="")

    video.release()
    print("\nProcessing completed!")

    # Find the detection with highest mean confidence
    if all_detections:
        best_detection = max(all_detections, key=lambda x: x['mean_confidence'])
        
        # Process the best detection
        letters = []
        numbers = []
        confidence_scores = []
        
        for char_info in best_detection['chars']:
            char = char_info['char']
            if char.isdigit():
                numbers.append(char)
            else:
                letters.append(char)
            confidence_scores.append(char_info['confidence'])

        plate_text = map_to_arabic(numbers, letters)
        best_detection['plate_text'] = plate_text
        
        # Display results
        plt.figure(figsize=(6, 4))
        plt.imshow(best_detection['plate_crop'])
        plt.title(f"Best Detection\nPlate Text: {plate_text}\n"
                f"Mean Confidence: {best_detection['mean_confidence']:.2f}")
        plt.axis('off')
        
        # print(f"\nBest Detection:")
        print(f"Plate Text: {plate_text}")
        print(f"Mean Confidence: {best_detection['mean_confidence']:.2f}")
        
        plt.show()
        
        return {
            'text': plate_text,
            'letters': letters,
            'numbers': numbers,
            'chars': best_detection['chars'],
            'mean_confidence': best_detection['mean_confidence'],
            'plate_crop': best_detection['plate_crop']
        }
    else:
        print("\nNo valid plate detections found in the video.")
        return None

# Usage example:
try:
    best_plate = process_uploaded_video(
        '2.mp4',
        yolo_model,
        plate_model,
        model_ocr,
        min_conf_threshold=0.25
    )
except Exception as e:
    print(f"An error occurred: {str(e)}")
# Out:
# 0: 384x640 1 License Plate, 97.0ms
# Speed: 3.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 53.7ms
# Speed: 2.8ms preprocess, 53.7ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 0.4%
# 0: 384x640 1 License Plate, 62.9ms
# Speed: 2.9ms preprocess, 62.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 79.2ms
# Speed: 2.1ms preprocess, 79.2ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 0.8%
# 0: 384x640 1 License Plate, 64.5ms
# Speed: 3.1ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 61.1ms
# Speed: 2.1ms preprocess, 61.1ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 1.2%
# 0: 384x640 1 License Plate, 65.4ms
# Speed: 2.8ms preprocess, 65.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 65.5ms
# Speed: 2.8ms preprocess, 65.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 1.6%
# 0: 384x640 1 License Plate, 76.8ms
# Speed: 3.3ms preprocess, 76.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 62.8ms
# Speed: 1.9ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 2.1%
# 0: 384x640 1 License Plate, 68.0ms
# Speed: 2.4ms preprocess, 68.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 0.8ms postprocess per image at shape (1, 3, 320, 640)
# Processing:
3ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 59.7%
# 0: 384x640 1 License Plate, 56.9ms
# Speed: 2.9ms preprocess, 56.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 48.7ms
# Speed: 2.1ms preprocess, 48.7ms inference, 1.5ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 60.1%
# 0: 384x640 1 License Plate, 55.5ms
# Speed: 2.9ms preprocess, 55.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 60.5%
# 0: 384x640 1 License Plate, 64.7ms
# Speed: 2.6ms preprocess, 64.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 69.0ms
# Speed: 2.4ms preprocess, 69.0ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 60.9%
# 0: 384x640 1 License Plate, 62.5ms
# Speed: 2.4ms preprocess, 62.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 54.7ms
# Speed: 1.9ms preprocess, 54.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 61.3%
# 0: 384x640 1 License Plate, 58.6ms
# Speed: 2.0ms preprocess, 58.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 55.5ms
# Speed: 2.0ms preprocess, 55.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 61.7%
# 0: 384x640 1 License Plate, 54.5ms
# Speed: 2.7ms preprocess, 54.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 64.1ms
# Speed: 2.3ms preprocess, 64.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 62.1%
# 0: 384x640 1 License Plate, 64.2ms
# Speed: 3.0ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 55.9ms
# Speed: 2.1ms preprocess, 55.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 62.6%
# 0: 384x640 1 License Plate, 62.1ms
# Speed: 2.3ms preprocess, 62.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 60.9ms
# Speed: 2.1ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 63.0%
# 0: 384x640 1 License Plate, 65.8ms
# Speed: 2.9ms preprocess, 65.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 6, 1 7, 2 8s, 2 saads, 60.5ms
# Speed: 2.1ms preprocess, 60.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 63.4%
# 0: 384x640 1 License Plate, 60.9ms
# Speed: 2.3ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 58.6ms
# Speed: 1.5ms preprocess, 58.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 63.8%
# 0: 384x640 1 License Plate, 59.9ms
# Speed: 1.9ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 61.1ms
# Speed: 2.2ms preprocess, 61.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 64.2%
# 0: 384x640 1 License Plate, 68.4ms
# Speed: 2.8ms preprocess, 68.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 53.4ms
# Speed: 2.2ms preprocess, 53.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 64.6%
# 0: 384x640 1 License Plate, 65.1ms
# Speed: 2.7ms preprocess, 65.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 61.1ms
# Speed: 1.6ms preprocess, 61.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 65.0%
# 0: 384x640 1 License Plate, 54.6ms
# Speed: 2.6ms preprocess, 54.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 54.4ms
# Speed: 2.0ms preprocess, 54.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 65.4%
# 0: 384x640 1 License Plate, 77.0ms
# Speed: 2.5ms preprocess, 77.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 87.7ms
# Speed: 4.0ms preprocess, 87.7ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 65.8%
# 0: 384x640 1 License Plate, 60.5ms
# Speed: 3.0ms preprocess, 60.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 52.9ms
# Speed: 1.5ms preprocess, 52.9ms inference, 0.9ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 66.3%
# 0: 384x640 1 License Plate, 58.7ms
# Speed: 2.5ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 56.2ms
# Speed: 1.5ms preprocess, 56.2ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 66.7%
# 0: 384x640 1 License Plate, 54.5ms
# Speed: 2.2ms preprocess, 54.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 59.0ms
# Speed: 2.3ms preprocess, 59.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 67.1%
# 0: 384x640 1 License Plate, 71.1ms
# ...
# Processing: 77.8%
# 0: 384x640 1 License Plate, 61.7ms
# Speed: 2.5ms preprocess, 61.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 52.5ms
# Speed: 2.1ms preprocess, 52.5ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 78.2%
# 0: 384x640 1 License Plate, 57.5ms
# Speed: 2.7ms preprocess, 57.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 50.7ms
# Speed: 1.5ms preprocess, 50.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 78.6%
# 0: 384x640 1 License Plate, 55.6ms
# Speed: 2.8ms preprocess, 55.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 51.0ms
# Speed: 2.1ms preprocess, 51.0ms inference, 1.7ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 79.0%
# 0: 384x640 1 License Plate, 64.9ms
# Speed: 2.9ms preprocess, 64.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 56.2ms
# Speed: 1.9ms preprocess, 56.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 79.4%
# 0: 384x640 1 License Plate, 57.2ms
# Speed: 2.6ms preprocess, 57.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 58.1ms
# Speed: 1.9ms preprocess, 58.1ms inference, 1.2ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 79.8%
# 0: 384x640 1 License Plate, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 50.7ms
# Speed: 1.8ms preprocess, 50.7ms inference, 1.4ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 80.2%
# 0: 384x640 1 License Plate, 62.1ms
# Speed: 2.6ms preprocess, 62.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 53.5ms
# Speed: 1.9ms preprocess, 53.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 80.7%
# 0: 384x640 1 License Plate, 58.6ms
# Speed: 2.6ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 52.9ms
# Speed: 1.8ms preprocess, 52.9ms inference, 0.9ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 81.1%
# 0: 384x640 1 License Plate, 59.5ms
# Speed: 3.2ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 58.2ms
# Speed: 2.0ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 81.5%
# 0: 384x640 1 License Plate, 59.9ms
# Speed: 3.0ms preprocess, 59.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 51.4ms
# Speed: 1.9ms preprocess, 51.4ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 81.9%
# 0: 384x640 1 License Plate, 59.6ms
# Speed: 1.9ms preprocess, 59.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 57.8ms
# Speed: 1.9ms preprocess, 57.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 82.3%
# 0: 384x640 1 License Plate, 58.0ms
# Speed: 2.0ms preprocess, 58.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 82.7%
# 0: 384x640 1 License Plate, 59.9ms
# Speed: 2.9ms preprocess, 59.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 55.6ms
# Speed: 1.9ms preprocess, 55.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 83.1%
# 0: 384x640 1 License Plate, 63.1ms
# Speed: 3.3ms preprocess, 63.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 56.5ms
# Speed: 2.0ms preprocess, 56.5ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 83.5%
# 0: 384x640 1 License Plate, 61.8ms
# Speed: 2.8ms preprocess, 61.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 6, 2 7s, 2 8s, 2 saads, 54.2ms
# Speed: 1.4ms preprocess, 54.2ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 84.0%
# 0: 384x640 1 License Plate, 61.4ms
# Speed: 2.4ms preprocess, 61.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 56.8ms
# Speed: 2.1ms preprocess, 56.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 84.4%
# 0: 384x640 1 License Plate, 56.9ms
# Speed: 2.1ms preprocess, 56.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 53.7ms
# Speed: 1.8ms preprocess, 53.7ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 84.8%
# 0: 384x640 1 License Plate, 57.6ms
# Speed: 2.2ms preprocess, 57.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 108.2ms
# Speed: 1.9ms preprocess, 108.2ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 85.2%
# 0: 384x640 1 License Plate, 74.4ms
# Speed: 6.2ms preprocess, 74.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 66.3ms
# Speed: 2.1ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 85.6%
# 0: 384x640 1 License Plate, 58.3ms
# Speed: 2.8ms preprocess, 58.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 6, 2 7s, 2 8s, 1 ain, 2 saads, 59.4ms
# Speed: 1.9ms preprocess, 59.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 86.0%
# 0: 384x640 1 License Plate, 59.1ms
# Speed: 2.7ms preprocess, 59.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 53.8ms
# Speed: 1.9ms preprocess, 53.8ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 86.4%
# 0: 384x640 1 License Plate, 58.9ms
# Speed: 2.9ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 86.8%
# 0: 384x640 1 License Plate, 55.7ms
# Speed: 2.6ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 52.5ms
# Speed: 2.1ms preprocess, 52.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 87.2%
# 0: 384x640 1 License Plate, 55.7ms
# Speed: 2.7ms preprocess, 55.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 57.5ms
# Speed: 2.2ms preprocess, 57.5ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 87.7%
# 0: 384x640 1 License Plate, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 55.9ms
# Speed: 2.2ms preprocess, 55.9ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 88.1%
# 0: 384x640 1 License Plate, 61.9ms
# Speed: 2.5ms preprocess, 61.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 53.7ms
# Speed: 1.8ms preprocess, 53.7ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 88.5%
# 0: 384x640 1 License Plate, 63.2ms
# Speed: 2.1ms preprocess, 63.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 50.4ms
# Speed: 1.7ms preprocess, 50.4ms inference, 1.0ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 88.9%
# 0: 384x640 1 License Plate, 58.0ms
# Speed: 2.9ms preprocess, 58.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 57.3ms
# Speed: 1.9ms preprocess, 57.3ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 89.3%
# 0: 384x640 1 License Plate, 61.3ms
# Speed: 2.4ms preprocess, 61.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 57.5ms
# Speed: 2.0ms preprocess, 57.5ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 89.7%
# 0: 384x640 1 License Plate, 58.6ms
# Speed: 3.1ms preprocess, 58.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 60.5ms
# Speed: 2.1ms preprocess, 60.5ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 90.1%
# 0: 384x640 1 License Plate, 59.4ms
# Speed: 2.7ms preprocess, 59.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 55.1ms
# Speed: 1.9ms preprocess, 55.1ms inference, 1.4ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 90.5%
# 0: 384x640 1 License Plate, 90.7ms
# Speed: 2.9ms preprocess, 90.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 57.6ms
# Speed: 2.4ms preprocess, 57.6ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 90.9%
# 0: 384x640 1 License Plate, 57.9ms
# Speed: 2.5ms preprocess, 57.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 53.4ms
# Speed: 1.6ms preprocess, 53.4ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 91.4%
# 0: 384x640 1 License Plate, 59.9ms
# Speed: 2.9ms preprocess, 59.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 55.7ms
# Speed: 1.9ms preprocess, 55.7ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 91.8%
# 0: 384x640 1 License Plate, 56.4ms
# Speed: 2.8ms preprocess, 56.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 92.2%
# 0: 384x640 1 License Plate, 57.5ms
# Speed: 2.3ms preprocess, 57.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 320x640 1 4, 1 7, 2 8s, 2 saads, 54.4ms
# Speed: 1.8ms preprocess, 54.4ms inference, 1.1ms postprocess per image at shape (1, 3, 320, 640)
# Processing: 92.6%
# 0: 384x640 1 License Plate, 58.9ms
# Speed: 2.8ms preprocess, 58.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 57.3ms
# Speed: 1.8ms preprocess, 57.3ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 93.0%
# 0: 384x640 1 License Plate, 54.7ms
# Speed: 2.6ms preprocess, 54.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 58.1ms
# Speed: 1.9ms preprocess, 58.1ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 93.4%
# 0: 384x640 1 License Plate, 61.3ms
# Speed: 2.6ms preprocess, 61.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 59.1ms
# Speed: 1.9ms preprocess, 59.1ms inference, 1.1ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 93.8%
# 0: 384x640 1 License Plate, 58.7ms
# Speed: 2.1ms preprocess, 58.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 2 saads, 55.6ms
# Speed: 2.3ms preprocess, 55.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 94.2%
# 0: 384x640 1 License Plate, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 2 saads, 58.9ms
# Speed: 2.3ms preprocess, 58.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 94.7%
# 0: 384x640 1 License Plate, 72.6ms
# Speed: 2.6ms preprocess, 72.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 59.9ms
# Speed: 2.3ms preprocess, 59.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 95.1%
# 0: 384x640 1 License Plate, 56.8ms
# Speed: 2.8ms preprocess, 56.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 2 saads, 56.3ms
# Speed: 2.3ms preprocess, 56.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 95.5%
# 0: 384x640 1 License Plate, 56.5ms
# Speed: 2.5ms preprocess, 56.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 2 saads, 54.6ms
# Speed: 2.0ms preprocess, 54.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 95.9%
# 0: 384x640 1 License Plate, 87.8ms
# Speed: 2.1ms preprocess, 87.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 2 saads, 60.4ms
# Speed: 2.1ms preprocess, 60.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 96.3%
# 0: 384x640 1 License Plate, 58.5ms
# Speed: 2.5ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 53.4ms
# Speed: 1.6ms preprocess, 53.4ms inference, 1.3ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 96.7%
# 0: 384x640 1 License Plate, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 97.1%
# 0: 384x640 1 License Plate, 58.0ms
# Speed: 2.2ms preprocess, 58.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 53.2ms
# Speed: 1.9ms preprocess, 53.2ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 97.5%
# 0: 384x640 1 License Plate, 61.3ms
# Speed: 2.6ms preprocess, 61.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 57.7ms
# Speed: 2.1ms preprocess, 57.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 97.9%
# 0: 384x640 1 License Plate, 58.2ms
# Speed: 2.3ms preprocess, 58.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 4, 1 7, 2 8s, 1 ain, 2 saads, 58.8ms
# Speed: 2.4ms preprocess, 58.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
# Processing: 98.4%
# 0: 384x640 1 License Plate, 58.6ms
# Speed: 2.8ms preprocess, 58.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 55.7ms
# Speed: 2.0ms preprocess, 55.7ms inference, 1.5ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 98.8%
# 0: 384x640 1 License Plate, 56.4ms
# Speed: 3.0ms preprocess, 56.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 64.1ms
# Speed: 1.5ms preprocess, 64.1ms inference, 1.2ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 99.2%
# 0: 384x640 1 License Plate, 61.8ms
# Speed: 3.1ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 58.4ms
# Speed: 2.2ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 99.6%
# 0: 384x640 1 License Plate, 71.3ms
# Speed: 2.9ms preprocess, 71.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 352x640 1 4, 1 7, 2 8s, 2 saads, 54.8ms
# Speed: 2.0ms preprocess, 54.8ms inference, 0.8ms postprocess per image at shape (1, 3, 352, 640)
# Processing: 100.0%
# Processing completed!
# Plate Text: ص ص ٨ ٧ ٨ ٤
# Mean Confidence: 0.93
